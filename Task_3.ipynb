# %% [markdown]
# ## Data Science And Business Analytics Intern At  GRIP @ The Sparks Foundation ##

# %% [markdown]
# ## Author :- Vedant Lotia ##

# %% [markdown]
# ## Task 3 :- Exploratory Data Analysis - Retail ##

# %% [markdown]
# ## Problem Statement:-  As a business manager, try to find out the weak areas where you can work to make more profit.What all business problems you can derive by exploring the data? ##

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
sales = pd.read_csv("C:\\Users\\HP\\Desktop\\SampleSuperstore.csv")
sales
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
sales.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
sales.nunique()
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %%
sales['Ship Mode'].unique()
# Out:
# array(['Second Class', 'Standard Class', 'First Class', 'Same Day'],
#       dtype=object)

# %%
sales['Country'].unique()
# Out:
# array(['United States'], dtype=object)

# %%
sales['Category'].unique()
# Out:
# array(['Furniture', 'Office Supplies', 'Technology'], dtype=object)

# %%
sales['Region'].unique()
# Out:
# array(['South', 'West', 'Central', 'East'], dtype=object)

# %%
new = sales.drop(['Postal Code','Country'],axis=1)
new
# Out:
#            Ship Mode    Segment             City       State Region  \
# 0       Second Class   Consumer        Henderson    Kentucky  South
# 1       Second Class   Consumer        Henderson    Kentucky  South
# 2       Second Class  Corporate      Los Angeles  California   West
# 3     Standard Class   Consumer  Fort Lauderdale     Florida  South
# 4     Standard Class   Consumer  Fort Lauderdale     Florida  South
# ...              ...        ...              ...         ...    ...
# 9989    Second Class   Consumer            Miami     Florida  South
# 9990  Standard Class   Consumer       Costa Mesa  California   West
# 9991  Standard Class   Consumer       Costa Mesa  California   West
# 9992  Standard Class   Consumer       Costa Mesa  California   West
# 9993    Second Class   Consumer      Westminster  California   West
#
#              Category Sub-Category     Sales  Quantity  Discount    Profit
# 0           Furniture    Bookcases  261.9600         2      0.00   41.9136
# ...

# %% [markdown]
# ## State Wise Analysis ##

# %%
ps = sales.groupby('State')[['Sales','Profit']].sum().sort_values(by='Sales',ascending=False)
ps[:].plot.bar(color=['blue','orange'],figsize=(15,8))
plt.title('Profit/Loss and Sales across states')
plt.xlabel('States')
plt.ylabel('Profit/Loss and Sales')
plt.show()

# %% [markdown]
# ### California has highest profit and Texas has lowest profit
# ### California has highest sales and Texas has lowest North Dekota

# %% [markdown]
# ## Region Wise Analysis ##

# %%
sales.groupby('Region')[['Profit','Sales']].sum().sort_values(by='Sales',ascending=False).plot.bar(color=['orange','maroon'],figsize=(10,8))
plt.ylabel('Profit/Loss and Sales')
plt.show()

# %% [markdown]
# ### West has highest profit and Central has lowest profit
# ### West has highest sales and South has lowest sales

# %% [markdown]
# ## City wise analysis

# %%
g = sales.groupby('City')[['Profit','Sales']].sum().sort_values(by='Sales',ascending=False)
g.plot.bar(color=['orange','maroon'],figsize=(25,18))

# %%
g.max
# Out:
# <bound method DataFrame.max of                    Profit       Sales
# City
# New York City  62036.9837  256368.161
# Los Angeles    30440.7579  175851.341
# Seattle        29156.0967  119540.742
# San Francisco  17507.3854  112669.092
# Philadelphia  -13837.7674  109077.013
# ...                   ...         ...
# Ormond Beach      -1.9656       2.808
# Pensacola         -1.4760       2.214
# Jupiter            0.1548       2.064
# Elyria            -1.3984       1.824
# Abilene           -3.7584       1.392
#
# [531 rows x 2 columns]>

# %%
g.min()
# Out:
# Profit   -13837.7674
# Sales         1.3920
# dtype: float64

# %% [markdown]
# ### New york City has Highest profit and sales.
# ### Philadelphia has least profit.
# ### Abilene has lowest sales.

# %% [markdown]
# # Ship-Mode Counts

# %%
sns.countplot(sales['Ship Mode'])
plt.show()

# %% [markdown]
# ### Standard class ship-mode is highest use by the customers.

# %% [markdown]
# # Profit with respect to category

# %%
plt.title("Percentage Profit with respect to Category")
plt.pie(sales['Profit'].groupby(sales['Category']).sum(),labels=sales['Profit'].groupby(sales['Category']).sum().index,autopct='%0.1f%%')
plt.show()

# %% [markdown]
# ### Technology category has highest profit on the other hand Furniture has lowest.

# %% [markdown]
# # Profit with respect to Sub-Category

# %%
plt.figure(figsize=(15,7))
plt.title("Profit vs Sub-Category ")
sns.barplot(x='Sub-Category',y='Profit',data=sales)
plt.show()

# %%
plt.figure(figsize=(18,8))
sns.countplot(sales['Sub-Category'])
plt.show()

# %% [markdown]
# ### Copiers sub-category has highest profit whereas tables has lowest.
# ### Binders sub-category has highest count whereas Copiers has lowest.

# %% [markdown]
# # Profit with respect to Discount

# %%
sns.barplot(data=sales, x="Discount", y="Profit")
plt.show()

# %% [markdown]
# ### If Seller give 0.1% discount then they will get highest profit however, if seller give more than 0.1% discount then they will be in loss.

# %% [markdown]
# # Profit with respect to segment

# %%
plt.title("%Profit with segment")
plt.pie(sales['Profit'].groupby(sales['Segment']).sum(),labels=sales['Profit'].groupby(sales['Segment']).sum().index,autopct='%0.1f%%')
plt.show()

# %% [markdown]
# ### Consumer segment has more profit comapare to other segments.

# %% [markdown]
# # <u>Summary:-</u>

# %% [markdown]
# ## <u> State Wise Analysis </u>

# %% [markdown]
# ### - California has highest profit and Texas has lowest profit
# ### - California has highest sales and Texas has lowest North Dekota

# %% [markdown]
# ## <u>Region Wise Analysis </u>

# %% [markdown]
# ### - West has highest profit and Central has lowest profit
# ### - West has highest sales and South has lowest sales

# %% [markdown]
# ## <u>City wise analysis</u>

# %% [markdown]
# ### - New york City has Highest profit and sales.
# ### - Philadelphia has least profit.
# ### - Abilene has lowest sales.

# %% [markdown]
# ## <u>Ship-Mode Counts</u>

# %% [markdown]
# ### - Standard class ship-mode is highest use by the customers.

# %% [markdown]
# ## <u>Profit with respect to category</u>

# %% [markdown]
# ### - Technology category has highest profit on the other hand Furniture has lowest.

# %% [markdown]
# ## <u>Profit with respect to Sub-Category</u>

# %% [markdown]
# ### - Copiers sub-category has highest profit whereas tables has lowest.
# ### - Binders sub-category has highest count whereas Copiers has lowest.

# %% [markdown]
# ## <u>Profit with respect to Discount</u>

# %% [markdown]
# ### - If Seller give 0.1% discount then they will get highest profit however, if seller give more than 0.1% discount then they will be in loss.

# %% [markdown]
# ## <u>Profit with respect to segment</u>

# %% [markdown]
# ### - Consumer segment has more profit comapare to other segments.

# %% [markdown]
# # Thank You
